# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
file_path = r'C:\Users\serik\OneDrive\Рабочий стол\machine learning\avocado\avocado_prices_with_noise.csv'
df = pd.read_csv(file_path)
display(df)
# Out:
#              Date   AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27   1.33 dollars      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20  $1.35 average      54876.98   674.28   44638.81   58.33
# 2      2015-12-13  $0.93 average     118220.22   794.70  109149.67  130.50
# 3      2015-12-06  $1.08 average      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29   1.28 dollars      51039.60   941.48   43838.39   75.78
# ...           ...            ...           ...      ...        ...     ...
# 18244  2018-02-04   1.63 dollars      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28   1.71 dollars      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21   1.87 dollars      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14  $1.93 average      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07  $1.62 average      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.isna().sum()
# Out:
# date            0
# averageprice    0
# total_volume    0
# 4046            0
# 4225            0
# 4770            0
# total_bags      0
# small_bags      0
# large_bags      0
# xlarge_bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
import re

# %%
pattern = r"(\d+[,.]?\d*)"

# %%
df["averageprice"] = df["averageprice"].str.extract(pattern)
df["averageprice"] = pd.to_numeric(df["averageprice"], errors="coerce")
df["averageprice"].isna().sum()
# Out:
# 0

# %%
print(df['date'].value_counts())
print(df['year'].value_counts())
# Out:
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: date, Length: 169, dtype: int64
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
df.dtypes
# Out:
# date             object
# averageprice    float64
# total_volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# total_bags      float64
# small_bags      float64
# large_bags      float64
# xlarge_bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df['year'] = df['year'].astype('object')

# %%
X = df.drop(["averageprice"], axis=1)
y = df["averageprice"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, shuffle=True, random_state=1)

# %%
numeric_features = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X_train.select_dtypes(include=['object']).columns

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
ohe_features = ['date', 'year']
oe_features = ['type', 'region']

# %%
numeric_transformer = Pipeline(steps=[
    ('scaler', RobustScaler())])
categorical_transformer_ohe = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
categorical_transformer_oe = Pipeline(steps=[
    ('ordinal_encoder', OrdinalEncoder())])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat_ohe', categorical_transformer_ohe, ohe_features),
        ('cat_oe', categorical_transformer_oe, oe_features)])

# %%
X_train_preprocessed = preprocessor.fit_transform(X_train)
X_val_preprocessed = preprocessor.transform(X_val)

# %%
X_train_preprocessed_ = X_train_preprocessed.toarray()
X_val_preprocessed_ = X_val_preprocessed.toarray()

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import MeanSquaredError
from sklearn.metrics import mean_squared_error

# %%
def create_model(input_shape, dropout_rate=0.2, weight_decay=0.0001):
    model = Sequential()
    model.add(layers.InputLayer(input_shape=input_shape))
    model.add(layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(1, activation='linear'))
    return model

# %%
def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    else:
        return lr * 0.1

# %%
input_shape = X_train_preprocessed_.shape[1]
model = create_model(input_shape)
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError(), metrics=['mse'])

callbacks = [LearningRateScheduler(scheduler, verbose=1)]
history = model.fit(X_train_preprocessed_, y_train, epochs=50, batch_size=32, validation_data=(X_val_preprocessed_, y_val), callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# 457/457 [==============================] - 1s 1ms/step - loss: 6.2076 - mse: 6.1858 - val_loss: 0.3046 - val_mse: 0.2834 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/50
# 457/457 [==============================] - 1s 1ms/step - loss: 1.1497 - mse: 1.1289 - val_loss: 0.3188 - val_mse: 0.2985 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.4734 - mse: 0.4535 - val_loss: 0.1791 - val_mse: 0.1595 - lr: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.3879 - mse: 0.3688 - val_loss: 0.1477 - val_mse: 0.1291 - lr: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.2256 - mse: 0.2073 - val_loss: 0.1274 - val_mse: 0.1095 - lr: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1726 - mse: 0.1549 - val_loss: 0.1151 - val_mse: 0.0977 - lr: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1452 - mse: 0.1281 - val_loss: 0.1117 - val_mse: 0.0947 - lr: 0.0010
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1202 - mse: 0.1033 - val_loss: 0.1051 - val_mse: 0.0883 - lr: 0.0010
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1199 - mse: 0.1032 - val_loss: 0.0981 - val_mse: 0.0815 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1289 - mse: 0.1125 - val_loss: 0.0983 - val_mse: 0.0820 - lr: 0.0010
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 11/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1067 - mse: 0.0904 - val_loss: 0.0959 - val_mse: 0.0798 - lr: 0.0010
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 12/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1018 - mse: 0.0859 - val_loss: 0.0907 - val_mse: 0.0749 - lr: 0.0010
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 13/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1005 - mse: 0.0848 - val_loss: 0.0904 - val_mse: 0.0749 - lr: 0.0010
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 14/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.1009 - mse: 0.0856 - val_loss: 0.0961 - val_mse: 0.0809 - lr: 0.0010
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 15/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0963 - mse: 0.0812 - val_loss: 0.0878 - val_mse: 0.0729 - lr: 0.0010
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 16/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0946 - mse: 0.0798 - val_loss: 0.0840 - val_mse: 0.0693 - lr: 0.0010
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 17/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0967 - mse: 0.0821 - val_loss: 0.0910 - val_mse: 0.0765 - lr: 0.0010
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 18/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0940 - mse: 0.0796 - val_loss: 0.0867 - val_mse: 0.0725 - lr: 0.0010
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 19/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0908 - mse: 0.0767 - val_loss: 0.0845 - val_mse: 0.0706 - lr: 0.0010
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 20/50
# 457/457 [==============================] - 1s 2ms/step - loss: 0.2172 - mse: 0.2031 - val_loss: 0.0869 - val_mse: 0.0728 - lr: 0.0010
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 21/50
# 457/457 [==============================] - 1s 2ms/step - loss: 0.0976 - mse: 0.0836 - val_loss: 0.0824 - val_mse: 0.0685 - lr: 0.0010
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 22/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0916 - mse: 0.0778 - val_loss: 0.0829 - val_mse: 0.0693 - lr: 0.0010
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 23/50
# 457/457 [==============================] - 1s 2ms/step - loss: 0.0888 - mse: 0.0753 - val_loss: 0.0816 - val_mse: 0.0681 - lr: 0.0010
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 24/50
# 457/457 [==============================] - 1s 2ms/step - loss: 0.0897 - mse: 0.0764 - val_loss: 0.0870 - val_mse: 0.0738 - lr: 0.0010
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 25/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0859 - mse: 0.0728 - val_loss: 0.0799 - val_mse: 0.0669 - lr: 0.0010
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 26/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0861 - mse: 0.0732 - val_loss: 0.0774 - val_mse: 0.0646 - lr: 0.0010
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 27/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0839 - mse: 0.0712 - val_loss: 0.0764 - val_mse: 0.0638 - lr: 0.0010
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 28/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0821 - mse: 0.0696 - val_loss: 0.0754 - val_mse: 0.0631 - lr: 0.0010
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 29/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0815 - mse: 0.0692 - val_loss: 0.0754 - val_mse: 0.0632 - lr: 0.0010
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 30/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0805 - mse: 0.0684 - val_loss: 0.0740 - val_mse: 0.0620 - lr: 0.0010
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 31/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0762 - mse: 0.0642 - val_loss: 0.0712 - val_mse: 0.0593 - lr: 1.0000e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.0000000474974514e-05.
# Epoch 32/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0748 - mse: 0.0629 - val_loss: 0.0710 - val_mse: 0.0590 - lr: 1.0000e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.0000000656873453e-06.
# Epoch 33/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0752 - mse: 0.0632 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.0000001111620805e-07.
# Epoch 34/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0765 - mse: 0.0646 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-07
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.000000082740371e-08.
# Epoch 35/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0761 - mse: 0.0642 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-08
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.000000082740371e-09.
# Epoch 36/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0755 - mse: 0.0635 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-09
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.000000082740371e-10.
# Epoch 37/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0752 - mse: 0.0633 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-10
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.000000082740371e-11.
# Epoch 38/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0745 - mse: 0.0626 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-11
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.000000082740371e-12.
# Epoch 39/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0750 - mse: 0.0631 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-12
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.0000001044244145e-13.
# Epoch 40/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0750 - mse: 0.0630 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-13
#
# Epoch 41: LearningRateScheduler setting learning rate to 1.0000001179769417e-14.
# Epoch 41/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0747 - mse: 0.0628 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-14
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.0000001518582595e-15.
# Epoch 42/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0749 - mse: 0.0629 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-15
#
# Epoch 43: LearningRateScheduler setting learning rate to 1.0000001095066122e-16.
# Epoch 43/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0741 - mse: 0.0622 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-16
#
# Epoch 44: LearningRateScheduler setting learning rate to 1.0000000830368326e-17.
# Epoch 44/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0746 - mse: 0.0627 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-17
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.0000000664932204e-18.
# Epoch 45/50
# 457/457 [==============================] - 1s 2ms/step - loss: 0.0747 - mse: 0.0628 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-18
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.000000045813705e-19.
# Epoch 46/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0758 - mse: 0.0639 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-19
#
# Epoch 47: LearningRateScheduler setting learning rate to 1.000000032889008e-20.
# Epoch 47/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0752 - mse: 0.0633 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-20
#
# Epoch 48: LearningRateScheduler setting learning rate to 1.0000000490448793e-21.
# Epoch 48/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0745 - mse: 0.0625 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-21
#
# Epoch 49: LearningRateScheduler setting learning rate to 1.0000000692397185e-22.
# Epoch 49/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0745 - mse: 0.0626 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-22
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.0000000944832675e-23.
# Epoch 50/50
# 457/457 [==============================] - 1s 1ms/step - loss: 0.0742 - mse: 0.0623 - val_loss: 0.0709 - val_mse: 0.0590 - lr: 1.0000e-23

# %%
y_val_pred = model.predict(X_val_preprocessed)

rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
print("RMSE for the validation set:", rmse)
# Out:
# 115/115 [==============================] - 0s 761us/step
# RMSE for the validation set: 0.242923307317651

# %% [markdown]
# **XGboostRegressor**

# %%
import xgboost as xgb

# %%
model = xgb.XGBRegressor()

# %%
params = {
    'n_estimators': [100, 500, 1000], 
    'learning_rate': [0.1, 0.01, 0.001],  
    'max_depth': [3, 5, 7] 
}

# %%
grid_search = GridSearchCV(estimator=model, param_grid=params, scoring='neg_root_mean_squared_error', cv=5, n_jobs=-1)
grid_search.fit(X_train_preprocessed, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 500, 1000]},
#              scoring='neg_root_mean_squared_error')

# %%
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# %%
y_val_pred = best_model.predict(X_val_preprocessed)
rmse = mean_squared_error(y_val, y_val_pred, squared=False)
print("RMSE:", rmse)
# Out:
# RMSE: 0.1336073766317054
